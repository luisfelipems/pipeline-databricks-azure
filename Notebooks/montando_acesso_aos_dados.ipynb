// %%
dbutils.fs.mkdirs("/mnt/dados")

// %%
%python
dbutils.fs.ls("/mnt")

// %%
val configs = Map(
  "fs.azure.account.auth.type" -> "OAuth",
  "fs.azure.account.oauth.provider.type" -> "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
  "fs.azure.account.oauth2.client.id" -> "cbc83822-cf15-470e-87ac-e67d4a0fae0b",
  "fs.azure.account.oauth2.client.secret" -> "btW8Q~rDR2sMaVCw7SEmcxrw2Go6bFpxVsL_6c3t",
  "fs.azure.account.oauth2.client.endpoint" -> "https://login.microsoftonline.com/81db0fb2-9067-442e-b798-bc2a7bb2d657/oauth2/token")
// Optionally, you can add <directory-name> to the source URI of your mount point.
dbutils.fs.mount(
  source = "abfss://imoveis@datalakealuraluisf1rst.dfs.core.windows.net/",
  mountPoint = "/mnt/dados",
  extraConfigs = configs)

// %%
%python
dbutils.fs.ls("/mnt/dados")
